# %% [markdown]
# <a href="https://colab.research.google.com/github/nollamae7-spec/DSRSP-Learning-how-to-use-GitHub/blob/main/DSHRP_Solar_Flares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd

# %%
url = 'https://github.com/frontiertechinstitute/datasets/raw/main/Solar%20Flares%20Dataset/solar_flares.csv'
df = pd.read_csv(url)

df
# Out:
#      zurich_class largest_spot_size spot_distribution  activity  evolution  \
# 0               C                 S                 O         1          2
# 1               D                 S                 O         1          3
# 2               C                 S                 O         1          3
# 3               D                 S                 O         1          3
# 4               D                 A                 O         1          3
# ...           ...               ...               ...       ...        ...
# 1384            H                 S                 X         1          2
# 1385            H                 S                 X         2          2
# 1386            C                 S                 O         1          2
# 1387            H                 R                 X         1          2
# 1388            B                 X                 O         1          1
#
#       prev_24hr_flare_activity  historically_complex  \
# ...

# %%
df["largest_spot_size"].unique()
# Out:
# array(['S', 'A', 'K', 'R', 'X', 'H'], dtype=object)
